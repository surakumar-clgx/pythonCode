# %% [markdown]
# # december

# %%
import os
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

from time import perf_counter,sleep
start = perf_counter()

# This is the input  folder
# path=r"\\filer-argentina-dev\Argentina\Shared Folder\Manikanda Gokul\Dec 2023\\"
path = r"C:\Users\surakumar\OneDrive - CoreLogic Solutions, LLC\Downloads\aug\\"

file_name= [file for file in os.listdir(path) if file.startswith('aug')]

#for i in file_name
#    print("vis","s.no ",i,"  ",file_name[i])

pd1 = pd.DataFrame()
p =1
for i in file_name:
    print(i)
    #vishnu excelfile
    #print("v - ",i)
    xls = pd.ExcelFile( rf"{path}{i}")

    n = pd.read_excel(xls,  sheet_name = "field_level_data")
    pd1 = pd.concat([pd1,n], axis=0)
    #print("v -",pd1)
    print(f"{p} ==> ",n.shape)
    print(pd1.shape)
    p+=1

print(pd1.shape)

end = perf_counter()
        
print("time---",end-start)
# Out:
# aug 1,2 extr report.xlsx
# 1--- (1008186, 9)
# (1008186, 9)
# aug 10 to 13 part 1 extr report.xlsx
# 2--- (885737, 9)
# (1893923, 9)
# aug 10 to 13 part 2 extr report.xlsx
# 3--- (408516, 9)
# (2302439, 9)
# aug 14,15 extr report.xlsx
# 4--- (885045, 9)
# (3187484, 9)
# aug 16 to 22 part 1 extr report.xlsx
# 5--- (869937, 9)
# (4057421, 9)
# aug 16 to 22 part 2 extr report.xlsx
# 6--- (790919, 9)
# (4848340, 9)
# aug 16 to 22 part 3 extr report.xlsx
# 7--- (162676, 9)
# (5011016, 9)
# aug 23 to 26 part 1 extr report.xlsx
# 8--- (851074, 9)
# (5862090, 9)
# aug 23 to 26 part 2 extr report.xlsx
# 9--- (583588, 9)
# (6445678, 9)
# aug 27 to 28 part 1 extr report.xlsx
# 10--- (733785, 9)
# (7179463, 9)
# aug 29 to 30  extr report.xlsx
# 11--- (733734, 9)
# (7913197, 9)
# aug 3,4,5 extr report.xlsx
# 12--- (973918, 9)
# (8887115, 9)
# aug 31  extr report.xlsx
# 13--- (558552, 9)
# (9445667, 9)
# aug 6,7 extr report.xlsx
# 14--- (723115, 9)
# (10168782, 9)
# aug 8,9 extr report.xlsx
# ...

# %%
v = pd1.copy()
v = v.drop_duplicates(keep="first")
#v = v[v["Field"].isin(['Buyer/Borrower/Defendant 1 First Name Or Company Name','Buyer/Borrower/Defendant 1 Last Name Or Company Code','Seller 1 First name','Seller 1 Last name'])]
v = v[v["Field"].isin(['Property Street Address (Part 1)','Property Street Address (Part 2)'])]

v = v[v["Deed_Category"].isin([' G',' Q'])]
v = v[v["Compare"] == 'Y']

# v

df2=v['Batch_ID']
df2.to_csv(r'C:\Users\surakumar\OneDrive - CoreLogic Solutions, LLC\Downloads\aug.csv')


# df2=v['Batch_ID']
# #no .of fields
# if df2.value_counts()==4:
#     print(df2)


#max.value_counts(dropna=false)
#max

# %%
b = v[['Batch_ID']].values.tolist()

# %%
len(b)
# Out:
# 5380

# %%
print(",".join(str(val[0]) for val in b[:999]))
# Out:
    print(k)
# Out:
# ('tx_images/2475126.zip', <http.client.HTTPMessage object at 0x0000023794BDFE10>)
# ('tx_images/2475130.zip', <http.client.HTTPMessage object at 0x0000023794C8B0D0>)
# ('tx_images/2475131.zip', <http.client.HTTPMessage object at 0x0000023794C8AB10>)
# ('tx_images/2475132.zip', <http.client.HTTPMessage object at 0x0000023794C8A750>)
# ('tx_images/2475157.zip', <http.client.HTTPMessage object at 0x0000023794BEAC10>)
# ('tx_images/2475213.zip', <http.client.HTTPMessage object at 0x0000023794BEA0D0>)
# ('tx_images/2475394.zip', <http.client.HTTPMessage object at 0x0000023794BEAB10>)
# ('tx_images/2475413.zip', <http.client.HTTPMessage object at 0x0000023794BEB190>)
# ('tx_images/2475487.zip', <http.client.HTTPMessage object at 0x0000023794CAD510>)
# ('tx_images/2475873.zip', <http.client.HTTPMessage object at 0x0000023794CAD890>)
# ('tx_images/2480192.zip', <http.client.HTTPMessage object at 0x0000023794CAE890>)
# ...

# %%
for batchid in b:
    k = urlretrieve(rf"https://clvisiontowerb.kfusw1prd.solutions.corelogic.com/download.php?path=ServerFiles/Pagesanddata/{batchid}/&zip={batchid}.zip&cond=Postprocessing&auto=Off", f"tx_images/{batchid}.zip")
    print(k)
# Out:
# ('tx_images/2475126.zip', <http.client.HTTPMessage object at 0x0000023794CAE1D0>)
# ('tx_images/2475130.zip', <http.client.HTTPMessage object at 0x0000023794CADED0>)
# ('tx_images/2475131.zip', <http.client.HTTPMessage object at 0x0000023794CAFF90>)
# ('tx_images/2475132.zip', <http.client.HTTPMessage object at 0x0000023794CB0710>)
# ('tx_images/2475157.zip', <http.client.HTTPMessage object at 0x0000023794CB0610>)
# ('tx_images/2475213.zip', <http.client.HTTPMessage object at 0x0000023794CB0050>)
# ('tx_images/2475394.zip', <http.client.HTTPMessage object at 0x0000023794CAFF90>)
# ('tx_images/2475413.zip', <http.client.HTTPMessage object at 0x0000023794CB0B50>)
# ('tx_images/2475487.zip', <http.client.HTTPMessage object at 0x0000023794CB06D0>)
# ('tx_images/2475873.zip', <http.client.HTTPMessage object at 0x0000023794CB01D0>)
# ('tx_images/2480192.zip', <http.client.HTTPMessage object at 0x0000023794CB0F10>)
# ...

# %%
import zipfile
import json

# %%
for p in Path("./New folder/").iterdir():
    with zipfile.ZipFile(p, mode="r") as archive:
        with archive.open("spacy.json") as file:
            data = json.load(file)
            print(p.name,data["6"])
# Out:
# 2473279.zip 12012023
# 2473400.zip 11302023
# 2473403.zip 11302023
# 2473406.zip 11302023
# 2473415.zip 12012023
# 2473435.zip 12012023
# 2473460.zip 12012023
# 2473842.zip 11272023
# 2473868.zip 11282023
# 2473990.zip 11302023
# 2474001.zip 11302023
# 2474466.zip 11072023
# 2474469.zip 11072023
# 2474476.zip 11062023

# %%
from pathlib import Path

# %%
for p in Path("./New folder/").iterdir():
    print(p)
# Out:
# New folder\2473279.zip
# New folder\2473400.zip
# New folder\2473403.zip
# New folder\2473406.zip
# New folder\2473415.zip
# New folder\2473435.zip
# New folder\2473460.zip
# New folder\2473842.zip
# New folder\2473868.zip
# New folder\2473990.zip
# New folder\2474001.zip
# New folder\2474466.zip
# New folder\2474469.zip
# New folder\2474476.zip

# %%
# Out:
# '2474476.zip'
